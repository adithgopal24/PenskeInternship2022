# %%
import sagemaker
import boto3
from sagemaker import get_execution_role

import pandas as pd
import numpy as np
import sys
import typing

sys.path.extend(['../src', '../config'])

region = boto3.Session().region_name
session = sagemaker.Session()
sm = boto3.Session().client(service_name='sagemaker',region_name=region)

import helpers.instance as ins
import helpers.s3 as s3_helper
import helpers.utils as ut
import helpers.athena as at

# READ YAML FILES AND STORE RELEVANT PATHS in dictionaries
dataset_cfg = ins.read_config('../config/datasets.yaml') 
config_cfg = ins.read_config('../config/config.yaml')
sql_cfg = ins.read_config('../config/sql.yaml')

# %%
input_files = [dataset_cfg['raw']['repair_base']['input'], dataset_cfg['raw']['base_query']['input']]
output_paths = [dataset_cfg['raw']['repair_base']['output_paths'], dataset_cfg['raw']['base_query']['output_paths']]

# %%
output_paths
# Out:
# ['s3://pske-stg-advanalytics/Projects/Unit_Sale_Risk_Interns/Data/Interim/repair_base/',
#  's3://pske-stg-advanalytics/Projects/Unit_Sale_Risk_Interns/Data/Interim/base_query/']

# %%
input_files
# Out:
# ['../sql/repair_base.txt', '../sql/base_query.txt']

# %%
# passing Athena variables
database=['ptledw_playarea', 'ptl_maintenance', 'ptl_connfleet', 'proactive_maint_db', 'ptl_adhoc']
workgroup='WG-Advanalytics'
tablename=['d_location_master','constellation_rules','ufch_depup', 'archive_pd_inference_scenario_output', 'corp_foilanl']

# %%
#Query string from a file, essentially, can get rid of
#s3 = boto3.client('s3', region)
#bucket_name = dataset_cfg['bucket']
#file = dataset_cfg['raw']['base_query']['input_file']
#file_obj = s3.get_object(Bucket=bucket_name,Key=file) #retrieves from S3
#file_data = file_obj['Body'].read() #reads contents of file
#query_string = file_data.decode() #method used to decode strings, which the file is
'''
def read_query_file(file_paths) -> list:
    """
        Reads queries from file and returns a list of query strings
        Args:
            file_paths (str):
        Returns:
            query_strings (list|str):
    """
    query_strings = []
    file_paths = ['../sql/repair_base.txt', '../sql/base_query.txt']
    for input_file in file_paths:
        query_string = open('../sql/base_query.txt').read()
        query_string = query_string.replace('\n',' ')
        query_string = query_string.replace('\t',' ')
        query_strings.append(query_string)
    return query_strings
'''
# Out:
# '\ndef read_query_file(file_paths) -> list:\n    """\n        Reads queries from file and returns a list of query strings\n        Args:\n            file_paths (str):\n        Returns:\n            query_strings (list|str):\n    """\n    query_strings = []\n    file_paths = [\'../sql/repair_base.txt\', \'../sql/base_query.txt\']\n    for input_file in file_paths:\n        query_string = open(\'../sql/base_query.txt\').read()\n        query_string = query_string.replace(\'\n\',\' \')\n        query_string = query_string.replace(\'\t\',\' \')\n        query_strings.append(query_string)\n    return query_strings\n'

# %%
#utilize loop to conduct all four queries
#use function to create query strings
#query

query_strings = ut.read_query_file(input_files)
#query_string = open('../sql/base_query.txt').read()
#query_string = query_string.replace('\n',' ')
#query_string = query_string.replace('\t',' ')
#query_string
#query_string = 'select * from ptl_maintenance.constellation_rules'

# %%
query_strings[0]
# Out:
# "SELECT  UNIT.UNIT_NUM,  job.PARTITION_KEY PARTITION_KEY,     SUM(job.LABOR_HOURS) LABOR_HOURS,     SUM(job.PARTS_COST) PARTS_COST,     SUM(job.LABOR_COST) LABOR_COST,     SUM(job.OUTSIDE_COST) OUTSIDE_COST,     SUM(CASE       WHEN prof.PROFILE_ID in ('9012','9013','9014','T','G','D1','9359','689','M1','5582','5886',                                 '686','6436','687','6136','690','STATEINS','1084',                                 '9465',    '552',    '5701',    '5700',    '6019',    '6345',    '5724',                                 '9317',    '7830',    '6344') then 1             ELSE 0         END) AS Major_PM,     SUM((CASE       WHEN prof.PROFILE_ID in ('ELEC INJ','5889','9035','6756','8924','A/C COMP','RADASSY','RPLTANK2', 'TURBO' ) or             ( comp.COMP_CODE in ('041','042','043','044','045','026','027') and (PARTS_COST+LABOR_COST+OUTSIDE_COST) >=800) then 1       ELSE 0      END))AS big_repair,  SUM(CASE    WHEN comp.COMP_CODE IN ('061','057') THEN 1   ELSE 0  END ) AS accidentsinci,     SUM(CASE       WHEN comp.COMP_CODE NOT IN ('016', '017','002', '011', '016', '017', '019' , '062', '063', '064', '065', '066', '067', '068', '069'                          ,'071','072','073','074','075','076','077','078','079','081','082','083','084') THEN 1             ELSE 0         END) AS total_repairs,     'model_build' AS flag_datatype FROM     ptledw_playarea.F_JOB_OIL_COST job          JOIN ptledw_playarea.D_UNIT unit ON           job.UNIT_KEY= unit.UNIT_KEY          JOIN ptledw_playarea.D_COMPONENT_CODE comp ON           job.COMPONENT_KEY= comp.COMP_KEY          JOIN ptledw_playarea.D_RO_SOURCE ro ON           job.RO_SOURCE_KEY= ro.RO_SOURCE_KEY          JOIN ptledw_playarea.D_ACCOUNT_CODE acc ON           job.ACCOUNT_CODE_KEY= acc.ACCOUNT_CODE_KEY          JOIN ptledw_playarea.D_PROFILE_MASTER prof ON           job.PROFILE_MASTER_KEY= prof.PROFILE_MASTER_KEY WHERE  unit.UNIT_CORP_CD IN ('HPTL','2000')  AND unit.UNIT_SOLD_DATE BETWEEN DATE '2019-01-01' AND CURRENT_DATE -- AND acc.ACCOUNT_CODE_GROUP1 IN ('LEASE', 'COMMERCIAL RENTAL','CONSUMER RENTAL')  AND LTRIM(RTRIM(unit.UNIT_CATEGORY)) IN ('TRUCK', 'TRACTOR', 'TRAILER')  AND job.PARTITION_KEY BETWEEN (YEAR(unit.ACT_VEH_INSERVDT)*100+ MONTH(unit.ACT_VEH_INSERVDT)) and (YEAR(unit.UNIT_SOLD_DATE)*100+ MONTH(unit.UNIT_SOLD_DATE))  AND ro.RO_SOURCE_CODE = 'ROS' GROUP BY unit.UNIT_NUM, job.PARTITION_KEY ORDER BY unit.UNIT_NUM, job.PARTITION_KEY"

# %%
query_strings
# Out:
# ["SELECT  UNIT.UNIT_NUM,  job.PARTITION_KEY PARTITION_KEY,     SUM(job.LABOR_HOURS) LABOR_HOURS,     SUM(job.PARTS_COST) PARTS_COST,     SUM(job.LABOR_COST) LABOR_COST,     SUM(job.OUTSIDE_COST) OUTSIDE_COST,     SUM(CASE       WHEN prof.PROFILE_ID in ('9012','9013','9014','T','G','D1','9359','689','M1','5582','5886',                                 '686','6436','687','6136','690','STATEINS','1084',                                 '9465',    '552',    '5701',    '5700',    '6019',    '6345',    '5724',                                 '9317',    '7830',    '6344') then 1             ELSE 0         END) AS Major_PM,     SUM((CASE       WHEN prof.PROFILE_ID in ('ELEC INJ','5889','9035','6756','8924','A/C COMP','RADASSY','RPLTANK2', 'TURBO' ) or             ( comp.COMP_CODE in ('041','042','043','044','045','026','027') and (PARTS_COST+LABOR_COST+OUTSIDE_COST) >=800) then 1       ELSE 0      END))AS big_repair,  SUM(CASE    WHEN comp.COMP_CODE IN ('061','057') THEN 1   ELSE 0  END ) AS accidentsinci,     SUM(CASE       WHEN comp.COMP_CODE NOT IN ('016', '017','002', '011', '016', '017', '019' , '062', '063', '064', '065', '066', '067', '068', '069'                          ,'071','072','073','074','075','076','077','078','079','081','082','083','084') THEN 1             ELSE 0         END) AS total_repairs,     'model_build' AS flag_datatype FROM     ptledw_playarea.F_JOB_OIL_COST job          JOIN ptledw_playarea.D_UNIT unit ON           job.UNIT_KEY= unit.UNIT_KEY          JOIN ptledw_playarea.D_COMPONENT_CODE comp ON           job.COMPONENT_KEY= comp.COMP_KEY          JOIN ptledw_playarea.D_RO_SOURCE ro ON           job.RO_SOURCE_KEY= ro.RO_SOURCE_KEY          JOIN ptledw_playarea.D_ACCOUNT_CODE acc ON           job.ACCOUNT_CODE_KEY= acc.ACCOUNT_CODE_KEY          JOIN ptledw_playarea.D_PROFILE_MASTER prof ON           job.PROFILE_MASTER_KEY= prof.PROFILE_MASTER_KEY WHERE  unit.UNIT_CORP_CD IN ('HPTL','2000')  AND unit.UNIT_SOLD_DATE BETWEEN DATE '2019-01-01' AND CURRENT_DATE -- AND acc.ACCOUNT_CODE_GROUP1 IN ('LEASE', 'COMMERCIAL RENTAL','CONSUMER RENTAL')  AND LTRIM(RTRIM(unit.UNIT_CATEGORY)) IN ('TRUCK', 'TRACTOR', 'TRAILER')  AND job.PARTITION_KEY BETWEEN (YEAR(unit.ACT_VEH_INSERVDT)*100+ MONTH(unit.ACT_VEH_INSERVDT)) and (YEAR(unit.UNIT_SOLD_DATE)*100+ MONTH(unit.UNIT_SOLD_DATE))  AND ro.RO_SOURCE_CODE = 'ROS' GROUP BY unit.UNIT_NUM, job.PARTITION_KEY ORDER BY unit.UNIT_NUM, job.PARTITION_KEY",
#  "SELECT  unit.UNIT_NUM,  agg.PARTITION_KEY AS PARTITION_KEY,  veh.VEHICLE_AGE_TOTAL_MONTHS,  loc.REGN_NUM || '-' || loc.REGN_NM AS REGION,  loc.AREA_NUM || '-' || loc.AREA_NM AS AREA,  loc.RDIST_NUM || '-' || loc.RDIST_SUFX || '-' || loc.RDIST_NM AS DISTRICT,  loc.DIST_NUM || '-' || loc.DIST_SUFX || '-' || loc.DIST_NM AS LOCATION,  unit.UNIT_MAKE_CODE,  unit.UNIT_MODEL,  unit.UNIT_MODEL_YEAR,  unit.UNIT_CATEGORY,  unit.UNIT_SIZE,  unit.UNIT_BODY_TYPE,  unit.UNIT_FUEL_TYPE,  unit.ACT_VEH_INSERVDT,  acc.ACCOUNT_CODE_GROUP1 AS PRODUCT_LINE,  unit.UNIT_SOLD_DATE ,  'model_build' AS flag_datatype,  MAX(agg.LTD_MILES) AS MILES FROM  ptledw_playarea.F_AGG_UNITCOST_EOM agg  JOIN ptledw_playarea.D_UNIT unit ON   unit.UNIT_KEY = agg.UNIT_KEY  JOIN ptledw_playarea.D_VEHICLE_AGE veh ON   agg.ACT_VEHICLE_AGE_KEY = veh.vehicle_age_key  JOIN ptledw_playarea.D_ACCOUNT_CODE acc ON   agg.ACCOUNT_CODE_KEY = acc.ACCOUNT_CODE_KEY  JOIN ptledw_playarea.D_LOCATION_MASTER loc ON   agg.LOCATION_MASTER_KEY = loc.LOCATION_MASTER_KEY WHERE  unit.UNIT_CORP_CD IN ('2000', 'HPTL')  AND LTRIM(RTRIM(unit.UNIT_CATEGORY)) IN ('TRUCK', 'TRACTOR', 'TRAILER')  AND unit.UNIT_SOLD_DATE BETWEEN DATE '2019-01-01' AND CURRENT_DATE GROUP BY  unit.UNIT_NUM,  agg.PARTITION_KEY,  veh.VEHICLE_AGE_TOTAL_MONTHS,  loc.REGN_NUM || '-' || loc.REGN_NM,  loc.AREA_NUM || '-' || loc.AREA_NM ,  loc.RDIST_NUM || '-' || loc.RDIST_SUFX || '-' || loc.RDIST_NM ,  loc.DIST_NUM || '-' || loc.DIST_SUFX || '-' || loc.DIST_NM,  unit.UNIT_MAKE_CODE,  unit.UNIT_MODEL,  unit.UNIT_MODEL_YEAR,  unit.UNIT_CATEGORY,  unit.UNIT_SIZE,  unit.UNIT_BODY_TYPE,  unit.UNIT_FUEL_TYPE,  unit.ACT_VEH_INSERVDT,  acc.ACCOUNT_CODE_GROUP1,  unit.UNIT_SOLD_DATE ORDER BY  unit.UNIT_NUM,  agg.PARTITION_KEY,  veh.VEHICLE_AGE_TOTAL_MONTHS"]

# %% [markdown]
# ## Read from Athena

# %%
# read data from Athena, add to loop (get_datasets_from_athena)
#df = at.get_data_from_athena(region=region,  query_string=query_string, 
                                   #   database=database[0],
                                    #  workgroup=workgroup)
dfs = at.get_datasets_from_athena(region = region, query_strings = query_strings, 
                                 database = database[0], catalog = 'AwsDataCatalog', 
                                 workgroup = workgroup)
# Out:
# Checking query status
# Current status: QUEUED
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: SUCCEEDED
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3524: DtypeWarning: Columns (0,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Checking query status
# Current status: QUEUED
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: RUNNING
# Current status: SUCCEEDED

# %% [markdown]
# ## Persist as a parquet

# %%
dfs
# Out:
# [         UNIT_NUM  PARTITION_KEY  VEHICLE_AGE_TOTAL_MONTHS  \
#  0          100001         201801                        44
#  1          100001         201802                        45
#  2          100001         201803                        46
#  3          100001         201804                        47
#  4          100001         201805                        48
#  ...           ...            ...                       ...
#  4839169  ZSS63809         202101                        49
#  4839170  ZSS63809         202102                        50
#  4839171  ZSS63809         202103                        51
#  4839172  ZSS63809         202104                        52
#  4839173  ZSS63809         202105                        53
#
#                        REGION                           AREA  \
#  0        0832-WESTERN REGION                  0642-MOUNTAIN
#  1        0832-WESTERN REGION                  0642-MOUNTAIN
#  2        0832-WESTERN REGION                  0642-MOUNTAIN
#  3        0832-WESTERN REGION                  0642-MOUNTAIN
#  4        0832-WESTERN REGION                  0642-MOUNTAIN
#  ...                      ...                            ...
#  4839169       0006-CORPORATE  0999-ADMINISTRATION AGGREGATE
#  4839170       0006-CORPORATE  0999-ADMINISTRATION AGGREGATE
#  4839171       0006-CORPORATE  0999-ADMINISTRATION AGGREGATE
#  4839172       0006-CORPORATE  0999-ADMINISTRATION AGGREGATE
#  4839173       0006-CORPORATE  0999-ADMINISTRATION AGGREGATE
#
#                                  DISTRICT                         LOCATION  \
#  0                0756-10-SOUTH LAS VEGAS          0756-10-SOUTH LAS VEGAS
#  1                0756-10-SOUTH LAS VEGAS          0756-10-SOUTH LAS VEGAS
#  2                0756-10-SOUTH LAS VEGAS          0756-10-SOUTH LAS VEGAS
#  3                0756-10-SOUTH LAS VEGAS          0756-10-SOUTH LAS VEGAS
#  4                0756-10-SOUTH LAS VEGAS          0756-10-SOUTH LAS VEGAS
#  ...                                  ...                              ...
#  4839169  6990-10-PENSKE FLEET MANAGEMENT  6990-10-PENSKE FLEET MANAGEMENT
#  4839170  6990-10-PENSKE FLEET MANAGEMENT  6990-10-PENSKE FLEET MANAGEMENT
#  4839171  6990-10-PENSKE FLEET MANAGEMENT  6990-10-PENSKE FLEET MANAGEMENT
#  4839172  6990-10-PENSKE FLEET MANAGEMENT  6990-10-PENSKE FLEET MANAGEMENT
#  4839173  6990-10-PENSKE FLEET MANAGEMENT  6990-10-PENSKE FLEET MANAGEMENT
#
#          UNIT_MAKE_CODE UNIT_MODEL  UNIT_MODEL_YEAR UNIT_CATEGORY UNIT_SIZE  \
#  0                  GMC     G33705             2014         TRUCK     LIGHT
#  1                  GMC     G33705             2014         TRUCK     LIGHT
#  2                  GMC     G33705             2014         TRUCK     LIGHT
#  3                  GMC     G33705             2014         TRUCK     LIGHT
#  4                  GMC     G33705             2014         TRUCK     LIGHT
#  ...                ...        ...              ...           ...       ...
#  4839169            HIN        268             2017         TRUCK    MEDIUM
#  4839170            HIN        268             2017         TRUCK    MEDIUM
#  4839171            HIN        268             2017         TRUCK    MEDIUM
#  4839172            HIN        268             2017         TRUCK    MEDIUM
#  4839173            HIN        268             2017         TRUCK    MEDIUM
#
#          UNIT_BODY_TYPE UNIT_FUEL_TYPE         ACT_VEH_INSERVDT  \
#  0             2000  06            GAS  2014-06-03 00:00:00.000
#  1             2000  06            GAS  2014-06-03 00:00:00.000
#  2             2000  06            GAS  2014-06-03 00:00:00.000
#  3             2000  06            GAS  2014-06-03 00:00:00.000
#  4             2000  06            GAS  2014-06-03 00:00:00.000
#  ...                ...            ...                      ...
#  4839169       1900  24         DIESEL  2017-01-01 00:00:00.000
#  4839170       1900  24         DIESEL  2017-01-01 00:00:00.000
#  4839171       1900  24         DIESEL  2017-01-01 00:00:00.000
#  4839172       1900  24         DIESEL  2017-01-01 00:00:00.000
#  4839173       1900  24         DIESEL  2017-01-01 00:00:00.000
#
#                         PRODUCT_LINE           UNIT_SOLD_DATE flag_datatype  \
#  0                             LEASE  2019-09-16 00:00:00.000   model_build
#  1                             LEASE  2019-09-16 00:00:00.000   model_build
#  2                             LEASE  2019-09-16 00:00:00.000   model_build
#  3                             LEASE  2019-09-16 00:00:00.000   model_build
#  4                             LEASE  2019-09-16 00:00:00.000   model_build
#  ...                             ...                      ...           ...
#  4839169  CONTRACT MAINTENANCE - PEG  2021-02-17 00:00:00.000   model_build
#  4839170  CONTRACT MAINTENANCE - PEG  2021-02-17 00:00:00.000   model_build
#  4839171  CONTRACT MAINTENANCE - PEG  2021-02-17 00:00:00.000   model_build
#  4839172  CONTRACT MAINTENANCE - PEG  2021-02-17 00:00:00.000   model_build
#  4839173  CONTRACT MAINTENANCE - PEG  2021-02-17 00:00:00.000   model_build
#
#           MILES
#  0        46108
#  1        46108
#  2        48116
#  3        48116
#  4        50347
#  ...        ...
#  4839169  17472
#  4839170  17491
#  4839171  17491
#  4839172  17491
#  4839173  17491
#
#  [4839174 rows x 19 columns],
#           UNIT_NUM  PARTITION_KEY  VEHICLE_AGE_TOTAL_MONTHS  \
#  0          100001         201801                        44
#  1          100001         201802                        45
#  2          100001         201803                        46
#  3          100001         201804                        47
#  4          100001         201805                        48
#  ...           ...            ...                       ...
#  4839169  ZSS63809         202101                        49
#  4839170  ZSS63809         202102                        50
#  4839171  ZSS63809         202103                        51
#  4839172  ZSS63809         202104                        52
#  4839173  ZSS63809         202105                        53
#
#                        REGION                           AREA  \
#  0        0832-WESTERN REGION                  0642-MOUNTAIN
#  1        0832-WESTERN REGION                  0642-MOUNTAIN
#  2        0832-WESTERN REGION                  0642-MOUNTAIN
#  3        0832-WESTERN REGION                  0642-MOUNTAIN
#  4        0832-WESTERN REGION                  0642-MOUNTAIN
#  ...                      ...                            ...
#  4839169       0006-CORPORATE  0999-ADMINISTRATION AGGREGATE
#  4839170       0006-CORPORATE  0999-ADMINISTRATION AGGREGATE
#  4839171       0006-CORPORATE  0999-ADMINISTRATION AGGREGATE
#  4839172       0006-CORPORATE  0999-ADMINISTRATION AGGREGATE
#  4839173       0006-CORPORATE  0999-ADMINISTRATION AGGREGATE
#
#                                  DISTRICT                         LOCATION  \
#  0                0756-10-SOUTH LAS VEGAS          0756-10-SOUTH LAS VEGAS
#  1                0756-10-SOUTH LAS VEGAS          0756-10-SOUTH LAS VEGAS
#  2                0756-10-SOUTH LAS VEGAS          0756-10-SOUTH LAS VEGAS
#  3                0756-10-SOUTH LAS VEGAS          0756-10-SOUTH LAS VEGAS
#  4                0756-10-SOUTH LAS VEGAS          0756-10-SOUTH LAS VEGAS
#  ...                                  ...                              ...
#  4839169  6990-10-PENSKE FLEET MANAGEMENT  6990-10-PENSKE FLEET MANAGEMENT
#  4839170  6990-10-PENSKE FLEET MANAGEMENT  6990-10-PENSKE FLEET MANAGEMENT
#  4839171  6990-10-PENSKE FLEET MANAGEMENT  6990-10-PENSKE FLEET MANAGEMENT
#  4839172  6990-10-PENSKE FLEET MANAGEMENT  6990-10-PENSKE FLEET MANAGEMENT
#  4839173  6990-10-PENSKE FLEET MANAGEMENT  6990-10-PENSKE FLEET MANAGEMENT
#
#          UNIT_MAKE_CODE UNIT_MODEL  UNIT_MODEL_YEAR UNIT_CATEGORY UNIT_SIZE  \
#  0                  GMC     G33705             2014         TRUCK     LIGHT
#  1                  GMC     G33705             2014         TRUCK     LIGHT
#  2                  GMC     G33705             2014         TRUCK     LIGHT
#  3                  GMC     G33705             2014         TRUCK     LIGHT
#  4                  GMC     G33705             2014         TRUCK     LIGHT
#  ...                ...        ...              ...           ...       ...
#  4839169            HIN        268             2017         TRUCK    MEDIUM
#  4839170            HIN        268             2017         TRUCK    MEDIUM
#  4839171            HIN        268             2017         TRUCK    MEDIUM
#  4839172            HIN        268             2017         TRUCK    MEDIUM
#  4839173            HIN        268             2017         TRUCK    MEDIUM
#
#          UNIT_BODY_TYPE UNIT_FUEL_TYPE         ACT_VEH_INSERVDT  \
#  0             2000  06            GAS  2014-06-03 00:00:00.000
#  1             2000  06            GAS  2014-06-03 00:00:00.000
#  2             2000  06            GAS  2014-06-03 00:00:00.000
#  3             2000  06            GAS  2014-06-03 00:00:00.000
#  4             2000  06            GAS  2014-06-03 00:00:00.000
#  ...                ...            ...                      ...
#  4839169       1900  24         DIESEL  2017-01-01 00:00:00.000
#  4839170       1900  24         DIESEL  2017-01-01 00:00:00.000
#  4839171       1900  24         DIESEL  2017-01-01 00:00:00.000
#  4839172       1900  24         DIESEL  2017-01-01 00:00:00.000
#  4839173       1900  24         DIESEL  2017-01-01 00:00:00.000
#
#                         PRODUCT_LINE           UNIT_SOLD_DATE flag_datatype  \
#  0                             LEASE  2019-09-16 00:00:00.000   model_build
#  1                             LEASE  2019-09-16 00:00:00.000   model_build
#  2                             LEASE  2019-09-16 00:00:00.000   model_build
#  3                             LEASE  2019-09-16 00:00:00.000   model_build
#  4                             LEASE  2019-09-16 00:00:00.000   model_build
#  ...                             ...                      ...           ...
#  4839169  CONTRACT MAINTENANCE - PEG  2021-02-17 00:00:00.000   model_build
#  4839170  CONTRACT MAINTENANCE - PEG  2021-02-17 00:00:00.000   model_build
#  4839171  CONTRACT MAINTENANCE - PEG  2021-02-17 00:00:00.000   model_build
#  4839172  CONTRACT MAINTENANCE - PEG  2021-02-17 00:00:00.000   model_build
#  4839173  CONTRACT MAINTENANCE - PEG  2021-02-17 00:00:00.000   model_build
#
#           MILES
#  0        46108
#  1        46108
#  2        48116
#  3        48116
#  4        50347
#  ...        ...
#  4839169  17472
#  4839170  17491
#  4839171  17491
#  4839172  17491
#  4839173  17491
#
#  [4839174 rows x 19 columns]]

# %%
#path = ['s3://pske-stg-advanalytics/Projects/Unit_Sale_Risk_Interns/Data/Interim/base_query/']
#wrapper function, list of paths and dataframes, put df in respective path
#path = dataset_cfg['raw']['base_query']['output_paths']
s3_helper.persist_files_to_path(dfs=dfs,
                       paths = output_paths,
                       filetype='parquet')

# %%
pd.read_parquet(output_paths[0])
# Out:
#          UNIT_NUM PARTITION_KEY VEHICLE_AGE_TOTAL_MONTHS               REGION  \
# 0          100001        201801                       44  0832-WESTERN REGION
# 1          100001        201802                       45  0832-WESTERN REGION
# 2          100001        201803                       46  0832-WESTERN REGION
# 3          100001        201804                       47  0832-WESTERN REGION
# 4          100001        201805                       48  0832-WESTERN REGION
# ...           ...           ...                      ...                  ...
# 4839169  ZSS63809        202101                       49       0006-CORPORATE
# 4839170  ZSS63809        202102                       50       0006-CORPORATE
# 4839171  ZSS63809        202103                       51       0006-CORPORATE
# 4839172  ZSS63809        202104                       52       0006-CORPORATE
# 4839173  ZSS63809        202105                       53       0006-CORPORATE
#
#                                   AREA                         DISTRICT  \
# 0                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
# 1                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
# 2                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
# 3                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
# 4                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
# ...                                ...                              ...
# 4839169  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
# 4839170  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
# 4839171  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
# 4839172  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
# 4839173  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#
#                                 LOCATION UNIT_MAKE_CODE UNIT_MODEL  \
# 0                0756-10-SOUTH LAS VEGAS            GMC     G33705
# 1                0756-10-SOUTH LAS VEGAS            GMC     G33705
# 2                0756-10-SOUTH LAS VEGAS            GMC     G33705
# 3                0756-10-SOUTH LAS VEGAS            GMC     G33705
# 4                0756-10-SOUTH LAS VEGAS            GMC     G33705
# ...                                  ...            ...        ...
# 4839169  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
# 4839170  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
# 4839171  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
# 4839172  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
# 4839173  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#
#         UNIT_MODEL_YEAR UNIT_CATEGORY UNIT_SIZE UNIT_BODY_TYPE UNIT_FUEL_TYPE  \
# 0                  2014         TRUCK     LIGHT       2000  06            GAS
# 1                  2014         TRUCK     LIGHT       2000  06            GAS
# 2                  2014         TRUCK     LIGHT       2000  06            GAS
# 3                  2014         TRUCK     LIGHT       2000  06            GAS
# 4                  2014         TRUCK     LIGHT       2000  06            GAS
# ...                 ...           ...       ...            ...            ...
# 4839169            2017         TRUCK    MEDIUM       1900  24         DIESEL
# 4839170            2017         TRUCK    MEDIUM       1900  24         DIESEL
# 4839171            2017         TRUCK    MEDIUM       1900  24         DIESEL
# 4839172            2017         TRUCK    MEDIUM       1900  24         DIESEL
# 4839173            2017         TRUCK    MEDIUM       1900  24         DIESEL
#
#                 ACT_VEH_INSERVDT                PRODUCT_LINE  \
# 0        2014-06-03 00:00:00.000                       LEASE
# 1        2014-06-03 00:00:00.000                       LEASE
# 2        2014-06-03 00:00:00.000                       LEASE
# 3        2014-06-03 00:00:00.000                       LEASE
# 4        2014-06-03 00:00:00.000                       LEASE
# ...                          ...                         ...
# 4839169  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
# 4839170  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
# 4839171  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
# 4839172  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
# 4839173  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#
#                   UNIT_SOLD_DATE flag_datatype  MILES
# 0        2019-09-16 00:00:00.000   model_build  46108
# 1        2019-09-16 00:00:00.000   model_build  46108
# 2        2019-09-16 00:00:00.000   model_build  48116
# 3        2019-09-16 00:00:00.000   model_build  48116
# 4        2019-09-16 00:00:00.000   model_build  50347
# ...                          ...           ...    ...
# 4839169  2021-02-17 00:00:00.000   model_build  17472
# 4839170  2021-02-17 00:00:00.000   model_build  17491
# 4839171  2021-02-17 00:00:00.000   model_build  17491
# 4839172  2021-02-17 00:00:00.000   model_build  17491
# 4839173  2021-02-17 00:00:00.000   model_build  17491
#
# [4839174 rows x 19 columns]

# %% [markdown]
# ## Read from Parquet

# %%
df2 = s3_helper.read_multiple_parquet_files(output_paths)
df2
# Out:
# [         UNIT_NUM PARTITION_KEY VEHICLE_AGE_TOTAL_MONTHS               REGION  \
#  0          100001        201801                       44  0832-WESTERN REGION
#  1          100001        201802                       45  0832-WESTERN REGION
#  2          100001        201803                       46  0832-WESTERN REGION
#  3          100001        201804                       47  0832-WESTERN REGION
#  4          100001        201805                       48  0832-WESTERN REGION
#  ...           ...           ...                      ...                  ...
#  4839169  ZSS63809        202101                       49       0006-CORPORATE
#  4839170  ZSS63809        202102                       50       0006-CORPORATE
#  4839171  ZSS63809        202103                       51       0006-CORPORATE
#  4839172  ZSS63809        202104                       52       0006-CORPORATE
#  4839173  ZSS63809        202105                       53       0006-CORPORATE
#
#                                    AREA                         DISTRICT  \
#  0                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
#  1                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
#  2                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
#  3                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
#  4                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
#  ...                                ...                              ...
#  4839169  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#  4839170  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#  4839171  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#  4839172  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#  4839173  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#
#                                  LOCATION UNIT_MAKE_CODE UNIT_MODEL  \
#  0                0756-10-SOUTH LAS VEGAS            GMC     G33705
#  1                0756-10-SOUTH LAS VEGAS            GMC     G33705
#  2                0756-10-SOUTH LAS VEGAS            GMC     G33705
#  3                0756-10-SOUTH LAS VEGAS            GMC     G33705
#  4                0756-10-SOUTH LAS VEGAS            GMC     G33705
#  ...                                  ...            ...        ...
#  4839169  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#  4839170  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#  4839171  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#  4839172  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#  4839173  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#
#          UNIT_MODEL_YEAR UNIT_CATEGORY UNIT_SIZE UNIT_BODY_TYPE UNIT_FUEL_TYPE  \
#  0                  2014         TRUCK     LIGHT       2000  06            GAS
#  1                  2014         TRUCK     LIGHT       2000  06            GAS
#  2                  2014         TRUCK     LIGHT       2000  06            GAS
#  3                  2014         TRUCK     LIGHT       2000  06            GAS
#  4                  2014         TRUCK     LIGHT       2000  06            GAS
#  ...                 ...           ...       ...            ...            ...
#  4839169            2017         TRUCK    MEDIUM       1900  24         DIESEL
#  4839170            2017         TRUCK    MEDIUM       1900  24         DIESEL
#  4839171            2017         TRUCK    MEDIUM       1900  24         DIESEL
#  4839172            2017         TRUCK    MEDIUM       1900  24         DIESEL
#  4839173            2017         TRUCK    MEDIUM       1900  24         DIESEL
#
#                  ACT_VEH_INSERVDT                PRODUCT_LINE  \
#  0        2014-06-03 00:00:00.000                       LEASE
#  1        2014-06-03 00:00:00.000                       LEASE
#  2        2014-06-03 00:00:00.000                       LEASE
#  3        2014-06-03 00:00:00.000                       LEASE
#  4        2014-06-03 00:00:00.000                       LEASE
#  ...                          ...                         ...
#  4839169  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#  4839170  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#  4839171  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#  4839172  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#  4839173  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#
#                    UNIT_SOLD_DATE flag_datatype  MILES
#  0        2019-09-16 00:00:00.000   model_build  46108
#  1        2019-09-16 00:00:00.000   model_build  46108
#  2        2019-09-16 00:00:00.000   model_build  48116
#  3        2019-09-16 00:00:00.000   model_build  48116
#  4        2019-09-16 00:00:00.000   model_build  50347
#  ...                          ...           ...    ...
#  4839169  2021-02-17 00:00:00.000   model_build  17472
#  4839170  2021-02-17 00:00:00.000   model_build  17491
#  4839171  2021-02-17 00:00:00.000   model_build  17491
#  4839172  2021-02-17 00:00:00.000   model_build  17491
#  4839173  2021-02-17 00:00:00.000   model_build  17491
#
#  [4839174 rows x 19 columns],
#           UNIT_NUM PARTITION_KEY VEHICLE_AGE_TOTAL_MONTHS               REGION  \
#  0          100001        201801                       44  0832-WESTERN REGION
#  1          100001        201802                       45  0832-WESTERN REGION
#  2          100001        201803                       46  0832-WESTERN REGION
#  3          100001        201804                       47  0832-WESTERN REGION
#  4          100001        201805                       48  0832-WESTERN REGION
#  ...           ...           ...                      ...                  ...
#  4839169  ZSS63809        202101                       49       0006-CORPORATE
#  4839170  ZSS63809        202102                       50       0006-CORPORATE
#  4839171  ZSS63809        202103                       51       0006-CORPORATE
#  4839172  ZSS63809        202104                       52       0006-CORPORATE
#  4839173  ZSS63809        202105                       53       0006-CORPORATE
#
#                                    AREA                         DISTRICT  \
#  0                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
#  1                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
#  2                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
#  3                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
#  4                        0642-MOUNTAIN          0756-10-SOUTH LAS VEGAS
#  ...                                ...                              ...
#  4839169  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#  4839170  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#  4839171  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#  4839172  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#  4839173  0999-ADMINISTRATION AGGREGATE  6990-10-PENSKE FLEET MANAGEMENT
#
#                                  LOCATION UNIT_MAKE_CODE UNIT_MODEL  \
#  0                0756-10-SOUTH LAS VEGAS            GMC     G33705
#  1                0756-10-SOUTH LAS VEGAS            GMC     G33705
#  2                0756-10-SOUTH LAS VEGAS            GMC     G33705
#  3                0756-10-SOUTH LAS VEGAS            GMC     G33705
#  4                0756-10-SOUTH LAS VEGAS            GMC     G33705
#  ...                                  ...            ...        ...
#  4839169  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#  4839170  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#  4839171  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#  4839172  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#  4839173  6990-10-PENSKE FLEET MANAGEMENT            HIN        268
#
#          UNIT_MODEL_YEAR UNIT_CATEGORY UNIT_SIZE UNIT_BODY_TYPE UNIT_FUEL_TYPE  \
#  0                  2014         TRUCK     LIGHT       2000  06            GAS
#  1                  2014         TRUCK     LIGHT       2000  06            GAS
#  2                  2014         TRUCK     LIGHT       2000  06            GAS
#  3                  2014         TRUCK     LIGHT       2000  06            GAS
#  4                  2014         TRUCK     LIGHT       2000  06            GAS
#  ...                 ...           ...       ...            ...            ...
#  4839169            2017         TRUCK    MEDIUM       1900  24         DIESEL
#  4839170            2017         TRUCK    MEDIUM       1900  24         DIESEL
#  4839171            2017         TRUCK    MEDIUM       1900  24         DIESEL
#  4839172            2017         TRUCK    MEDIUM       1900  24         DIESEL
#  4839173            2017         TRUCK    MEDIUM       1900  24         DIESEL
#
#                  ACT_VEH_INSERVDT                PRODUCT_LINE  \
#  0        2014-06-03 00:00:00.000                       LEASE
#  1        2014-06-03 00:00:00.000                       LEASE
#  2        2014-06-03 00:00:00.000                       LEASE
#  3        2014-06-03 00:00:00.000                       LEASE
#  4        2014-06-03 00:00:00.000                       LEASE
#  ...                          ...                         ...
#  4839169  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#  4839170  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#  4839171  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#  4839172  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#  4839173  2017-01-01 00:00:00.000  CONTRACT MAINTENANCE - PEG
#
#                    UNIT_SOLD_DATE flag_datatype  MILES
#  0        2019-09-16 00:00:00.000   model_build  46108
#  1        2019-09-16 00:00:00.000   model_build  46108
#  2        2019-09-16 00:00:00.000   model_build  48116
#  3        2019-09-16 00:00:00.000   model_build  48116
#  4        2019-09-16 00:00:00.000   model_build  50347
#  ...                          ...           ...    ...
#  4839169  2021-02-17 00:00:00.000   model_build  17472
#  4839170  2021-02-17 00:00:00.000   model_build  17491
#  4839171  2021-02-17 00:00:00.000   model_build  17491
#  4839172  2021-02-17 00:00:00.000   model_build  17491
#  4839173  2021-02-17 00:00:00.000   model_build  17491
#
#  [4839174 rows x 19 columns]]
